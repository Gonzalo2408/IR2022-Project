# %%
import xml.etree.ElementTree as ET 

DEV_QUERIES = 100
TEST_QUERIES = 1000
TRAIN_QUERIES = 100

RUN_FILE = 'lm_jm.run'
stats = {'dev': DEV_QUERIES, 'train':TRAIN_QUERIES, 'test':TEST_QUERIES}
with open(RUN_FILE) as f:
    file = f.readlines()

print(len(file))
# Out:
# 50000

# %%
# Pass the path of the xml document 

for key in stats.keys():
    output = ""
    iters = stats[key]
    location = "../TREC_COVID_TOPICS/" + str(key) + "_topics_v2.xml"
    tree = ET.parse(location)
    for i in range(len(tree.getroot())):
        query = tree.getroot()[i].attrib['number']
        file = open('lm_jm.run', 'r')
        j = 0
        for line in file:
            j += 1
            if int(line[0]) == int(query):
                begin = j
            if int(line[0]) == (int(query) + 1):
                end = j
        print(begin)
        print(end)

        

        # Find first line in run file that contains specific query id
        # Add the amount of queries needed after that one to the output string
        # Write output string to lm_jm_v2.run file

    # 
    # open(f"{key}_lm_jm_v2.run", "w").write(output_str)
# Out:
# 39000
# 49000
# 39000
# 49000
# 39000
# 49000
# 39000
# 49000
# 39000
# 49000
# 4
# 19000
# 29000
# 29000
# 39000
# 49000
# 50000
# 50000
# 6000
# 6000
# 7000
# 7000
# 8000
# 8000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 39
# 9000
# 9000
# 9000
# 9000
# 9000
# 9000
# 39000
# 49000
# 39000
# 49000
# 4
